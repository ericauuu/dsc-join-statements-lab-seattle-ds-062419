# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.Connection('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
cur.execute("""SELECT * FROM offices LIMIT 5""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#   officeCode           city            phone              addressLine1  \
# 0          1  San Francisco  +1 650 219 4782         100 Market Street
# 1          2         Boston  +1 215 837 0825          1550 Court Place
# 2          3            NYC  +1 212 555 3000      523 East 53rd Street
# 3          4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo  +81 33 224 5000               4-1 Kioicho
#
#   addressLine2       state country postalCode territory
# 0    Suite 300          CA     USA      94080        NA
# 1    Suite 102          MA     USA      02107        NA
# 2      apt. 5A          NY     USA      10022        NA
# 3                           France      75017      EMEA
# 4               Chiyoda-Ku   Japan   102-8578     Japan

# %%
cur.execute("""SELECT * FROM employees LIMIT 5""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1002     Murphy     Diane     x5800
# 1           1056  Patterson      Mary     x4611
# 2           1076   Firrelli      Jeff     x9273
# 3           1088  Patterson   William     x4871
# 4           1102     Bondur    Gerard     x5408
#
#                              email officeCode reportsTo              jobTitle
# 0     dmurphy@classicmodelcars.com          1                       President
# 1   mpatterso@classicmodelcars.com          1      1002              VP Sales
# 2   jfirrelli@classicmodelcars.com          1      1002          VP Marketing
# 3  wpatterson@classicmodelcars.com          6      1056  Sales Manager (APAC)
# 4     gbondur@classicmodelcars.com          4      1056   Sale Manager (EMEA)

# %%
cur.execute("""SELECT lastName, firstName FROM employees e
                        JOIN offices o
                        USING (officeCode)
                        WHERE o.city = 'Boston';""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#     lastName firstName
# 0   Firrelli     Julie
# 1  Patterson     Steve

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
cur.execute("""SELECT city, officeCode, count(officeCode) as num_employee
                        FROM employees e
                        JOIN offices o
                        USING (officeCode)
                        GROUP BY officeCode
                        ORDER BY city asc;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#             city officeCode  num_employee
# 0         Boston          2             2
# 1         London          7             2
# 2            NYC          3             2
# 3          Paris          4             5
# 4  San Francisco          1             6
# 5         Sydney          6             4
# 6          Tokyo          5             2

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
cur.execute("""SELECT productName, employeeNumber, firstName, lastName 
                      FROM products p
                      JOIN orderdetails od
                      USING (productCode)
                      JOIN orders o
                      USING (orderNumber)
                      JOIN customers c 
                      USING (customerNumber)
                      JOIN employees e
                      ON c.salesRepEmployeeNumber = e.employeeNumber             
                      ORDER BY employeeNumber desc ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
#print(len(df))
# Out:
#                                    productName employeeNumber firstName  \
# 0                     1952 Alpine Renault 1300           1702    Martin
# 1                          1972 Alfa Romeo GTA           1702    Martin
# 2                       1962 LanciaA Delta 16V           1702    Martin
# 3                            1968 Ford Mustang           1702    Martin
# 4                            1968 Ford Mustang           1702    Martin
# 5                            2001 Ferrari Enzo           1702    Martin
# 6                            2001 Ferrari Enzo           1702    Martin
# 7                               1958 Setra Bus           1702    Martin
# 8                           1969 Corvair Monza           1702    Martin
# 9                           1968 Dodge Charger           1702    Martin
# 10                          1968 Dodge Charger           1702    Martin
# 11                            1969 Ford Falcon           1702    Martin
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
cur.execute("""SELECT productName,
                      employeeNumber, 
                      firstName, 
                      lastName,
                      count(productCode) as num_prod
                      FROM products p
                      JOIN orderdetails od
                      USING (productCode)
                      JOIN orders o
                      USING (orderNumber)
                      JOIN customers c 
                      USING (customerNumber)
                      JOIN employees e
                      ON c.salesRepEmployeeNumber = e.employeeNumber
                      GROUP BY productName
                      ORDER BY firstName desc;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#                                      productName employeeNumber firstName  \
# 0                          18th century schooner           1216     Steve
# 1                              1903 Ford Model A           1216     Steve
# 2                            1904 Buick Runabout           1216     Steve
# 3               1912 Ford Model T Delivery Wagon           1216     Steve
# 4       1936 Mercedes-Benz 500K Special Roadster           1216     Steve
# 5                           1937 Lincoln Berline           1216     Steve
# 6                       1940 Ford Delivery Sedan           1216     Steve
# 7                            1972 Alfa Romeo GTA           1216     Steve
# 8                         1999 Yamaha Speed Boat           1216     Steve
# 9                       Collectable Wooden Train           1216     Steve
# 10                                    Pont Yacht           1216     Steve
# 11                                 The Mayflower           1216     Steve
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
